# %%
import numpy as np

# %%
patients_data = np.array([
[45, 80, 200, 120],
[60, 90, 240, 140],
[30, 70, 180, 110],
[50, 85, 220, 130],
[65, 95, 260, 150]
])
patients_data
# Out:
# array([[ 45,  80, 200, 120],
#        [ 60,  90, 240, 140],
#        [ 30,  70, 180, 110],
#        [ 50,  85, 220, 130],
#        [ 65,  95, 260, 150]])

# %%
data_shape = patients_data.shape
data_shape
# Out:
# (5, 4)

# %%
rowNum = data_shape = patients_data.shape[0]
rowNum
# Out:
# 5

# %%
colNum = data_shape = patients_data.shape[1]
colNum
# Out:
# 4

# %%
firstPatinet = patients_data[0]
firstPatinet
# Out:
# array([ 45,  80, 200, 120])

# %%
age = patients_data[:,0]
age
# Out:
# array([45, 60, 30, 50, 65])

# %%
blood_pressure =  patients_data[:,3]
blood_pressure
# Out:
# array([120, 140, 110, 130, 150])

# %%
average = np.mean(patients_data)
print(average)
# Out:
# 121.0

# %%
maximum_heart_rate = np.max(patients_data[:, 1])
print(maximum_heart_rate)
# Out:
# 95

# %%
minmum_cholesterol = np.min(patients_data[:, 2])
print(minmum_cholesterol)
# Out:
# 180

# %%
blood_pruser_more_than130=np.where(patients_data[:, -1] > 130)
print(patients_data[blood_pruser_more_than130])
# Out:
# [[ 60  90 240 140]
#  [ 65  95 260 150]]

# %%
cholesterol_more_than_orequal240 =np.where(patients_data[:, 2] >=240)
print(patients_data[cholesterol_more_than_orequal240])
# Out:
# [[ 60  90 240 140]
#  [ 65  95 260 150]]

# %%
age_above50 = np.where(patients_data[:, 0] > 50)
print(patients_data[age_above50])
# Out:
# [[ 60  90 240 140]
#  [ 65  95 260 150]]

# %%
#high_risk
#blood_pruser= patients_data[:, -1] > 140
#cholesterol=patients_data[:, 2] >240
highr_risk = np.where((patients_data[:, -1] > 140) |(patients_data[:, 2] >240),"High Risk","Stable")
#high_risk = np.any([blood_pruser,cholesterol],axis=0)
print(high_risk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 #high_risk
#       2 #blood_pruser= patients_data[:, -1] > 140
#       3 #cholesterol=patients_data[:, 2] >240
# ----> 4 highr_risk = np.where((patients_data[:, -1] > 140) |(patients_data[:, 2] >240),"High Risk","Stable")
#       5 #high_risk = np.any([blood_pruser,cholesterol],axis=0)
#       6 print(high_risk)
#
# NameError: name 'patients_data' is not defined

# %%
#Compare Groups
under50 = patients_data[patients_data[:, 0] < 50]
print(under50)
print("\n")
above50 = patients_data[patients_data[:, 0] >= 50]
print(above50)
avg_under50 = np.mean(under50[:, 1])
avg_above50 = np.mean(above50[:, 1])

print("Avg heart rate (under 50):", avg_under50)
print("Avg heart rate (50 and above):", avg_above50)
# Out:
# [[ 45  80 200 120]
#  [ 30  70 180 110]]
#
#
# [[ 60  90 240 140]
#  [ 50  85 220 130]
#  [ 65  95 260 150]]
# Avg heart rate (under 50): 75.0
# Avg heart rate (50 and above): 90.0

# %%
#Extreme Cases
blood_pressure =  patients_data[:,3]
Highest_blood_pressure = np.max(blood_pressure)
print(Highest_blood_pressure)
heart_rate = patients_data[:,1]
lowes_heart_rate = np.min(heart_rate)
print(lowes_heart_rate
# Out:
# 150
# 70

# %%
# Relationship Thinking
